# %%
import pandas as pd
import numpy as np

# %%
# 初始化变量以存储所有csv文件的指标结果
r2_scores = []
maes = []
rmses = []

# 从csv中逐个读取并计算指标
for i in range(1, 73):  # csv文件名为data1.csv至data72.csv
    filename1 = r'./results/TCI_prediction_of_road{}.xlsx'.format(i)
    df1 = pd.read_excel(filename1)  # 读取CSV文件
    predicted_values = df1['TCI_prediction_of_road{}'.format(i)]
    
    filename2 = r'./data/road{}-test.csv'.format(i)
    df2 = pd.read_csv(filename2)  # 读取CSV文件
    true_values = df2['EXPONENT']

    # 计算R平方值
    ss_res = np.sum((true_values - predicted_values) ** 2)
    ss_tot = np.sum((true_values - np.mean(true_values)) ** 2)
    r2 = 1 - (ss_res / ss_tot)
    r2_scores.append(r2)

    # 计算平均绝对误差MAE
    mae = np.mean(np.abs(true_values - predicted_values))
    maes.append(mae)

    # 计算均方根误差RMSE
    rmse = np.sqrt(np.mean((true_values - predicted_values) ** 2))
    rmses.append(rmse)

for i in range(72):
    print(f"在{i}上的结果：")
    print(f"R方平方值：{r2_scores[i]}")
    print(f"平均绝对误差MAE：{maes[i]}")
    print(f"均方根误差RMSE：{rmses[i]}")
# Out:
# 在0上的结果：
# R方平方值：0.07092198581560283
# 平均绝对误差MAE：0.7291666666666666
# 均方根误差RMSE：0.9537935951882998
# 在1上的结果：
# R方平方值：0.05604719764011801
# 平均绝对误差MAE：0.9583333333333334
# 均方根误差RMSE：1.25
# 在2上的结果：
# R方平方值：-0.11671190383869723
# 平均绝对误差MAE：0.5
# 均方根误差RMSE：0.7453559924999299
# 在3上的结果：
# R方平方值：0.22012076144237724
# 平均绝对误差MAE：1.2256944444444444
# 均方根误差RMSE：1.5645819462932156
# 在4上的结果：
# R方平方值：0.022521506007239456
# 平均绝对误差MAE：0.8958333333333334
# 均方根误差RMSE：1.1426091000668408
# 在5上的结果：
# R方平方值：0.04236227765116096
# 平均绝对误差MAE：1.7951388888888888
# 均方根误差RMSE：2.5214358784012116
# 在6上的结果：
# R方平方值：0.17981987482827055
# 平均绝对误差MAE：1.7777777777777777
# 均方根误差RMSE：2.0361319538117693
# 在7上的结果：
# R方平方值：0.19186914619247997
# 平均绝对误差MAE：1.71875
# 均方根误差RMSE：2.143303524935281
# 在8上的结果：
# R方平方值：0.20238095238095233
# 平均绝对误差MAE：1.2951388888888888
# 均方根误差RMSE：1.7390530628924339
# 在9上的结果：
# R方平方值：-0.050292596047833094
# 平均绝对误差MAE：0.8298611111111112
# 均方根误差RMSE：1.159202311936963
# 在10上的结果：
# R方平方值：0.15235897889282146
# 平均绝对误差MAE：1.625
# 均方根误差RMSE：1.8929694486000912
# 在11上的结果：
# R方平方值：0.20238095238095233
# 平均绝对误差MAE：1.2951388888888888
# 均方根误差RMSE：1.7390530628924339
# 在12上的结果：
# R方平方值：0.017631169134807556
# 平均绝对误差MAE：1.2743055555555556
# 均方根误差RMSE：1.6842819109506446
# 在13上的结果：
# R方平方值：0.06440300404763555
# 平均绝对误差MAE：1.1840277777777777
# 均方根误差RMSE：1.6718668873115732
# 在14上的结果：
# R方平方值：0.1111566266181927
# 平均绝对误差MAE：1.2951388888888888
# 均方根误差RMSE：1.5172617880027603
# 在15上的结果：
# R方平方值：-0.1019142337717891
# 平均绝对误差MAE：0.7569444444444444
# 均方根误差RMSE：1.0573814617041266
# 在16上的结果：
# R方平方值：0.2393519034195576
# 平均绝对误差MAE：1.8090277777777777
# 均方根误差RMSE：2.069118169655856
# 在17上的结果：
# R方平方值：0.1322103597190425
# 平均绝对误差MAE：1.4131944444444444
# 均方根误差RMSE：1.758905909933786
# 在18上的结果：
# R方平方值：0.06175637393767708
# 平均绝对误差MAE：1.25
# 均方根误差RMSE：1.5986105077709065
# 在19上的结果：
# R方平方值：-0.06606724003127473
# 平均绝对误差MAE：1.1180555555555556
# 均方根误差RMSE：1.4505745987941008
# 在20上的结果：
# R方平方值：0.046465376966190686
# 平均绝对误差MAE：0.6770833333333334
# 均方根误差RMSE：1.0086432030758503
# 在21上的结果：
# R方平方值：-1.0109571382533034
# 平均绝对误差MAE：0.6701388888888888
# 均方根误差RMSE：0.8228507357554792
# 在22上的结果：
# R方平方值：0.06146125268852243
# 平均绝对误差MAE：0.8819444444444444
# 均方根误差RMSE：1.25
# 在23上的结果：
# R方平方值：0.015525664521164217
# 平均绝对误差MAE：1.1875
# 均方根误差RMSE：1.550089603144856
# 在24上的结果：
# R方平方值：-0.04360450044071129
# 平均绝对误差MAE：1.2534722222222223
# 均方根误差RMSE：1.47784565424735
# 在25上的结果：
# R方平方值：0.23638784113601063
# 平均绝对误差MAE：0.6423611111111112
# 均方根误差RMSE：0.9109671295448103
# 在26上的结果：
# R方平方值：0.3748688815727981
# 平均绝对误差MAE：0.5798611111111112
# 均方根误差RMSE：0.8518770125108697
# 在27上的结果：
# R方平方值：0.060994361865709945
# 平均绝对误差MAE：0.7395833333333334
# 均方根误差RMSE：0.8917056066263623
# 在28上的结果：
# R方平方值：-1.1925086049807656
# 平均绝对误差MAE：0.6458333333333334
# 均方根误差RMSE：0.8079466429027216
# 在29上的结果：
# R方平方值：-0.2846456474760346
# 平均绝对误差MAE：0.8125
# 均方根误差RMSE：1.0573814617041266
# 在30上的结果：
# R方平方值：0.11920103772291513
# 平均绝对误差MAE：0.75
# 均方根误差RMSE：1.0034662148993578
# 在31上的结果：
# R方平方值：-0.30867413388903353
# 平均绝对误差MAE：0.4895833333333333
# 均方根误差RMSE：0.7383352144445562
# 在32上的结果：
# R方平方值：-0.08527330440606895
# 平均绝对误差MAE：1.1770833333333333
# 均方根误差RMSE：1.498842145717079
# 在33上的结果：
# R方平方值：-0.09102716744236372
# 平均绝对误差MAE：0.4583333333333333
# 均方根误差RMSE：0.6972166887783963
# 在34上的结果：
# R方平方值：-0.08233989464929303
# 平均绝对误差MAE：1.0347222222222223
# 均方根误差RMSE：1.3017082793177757
# 在35上的结果：
# R方平方值：0.09995350999535102
# 平均绝对误差MAE：0.6180555555555556
# 均方根误差RMSE：0.9166666666666666
# 在36上的结果：
# R方平方值：0.12561963486881877
# 平均绝对误差MAE：0.6180555555555556
# 均方根误差RMSE：0.8858454843945541
# 在37上的结果：
# R方平方值：0.3615157941119772
# 平均绝对误差MAE：0.8194444444444444
# 均方根误差RMSE：1.0573814617041266
# 在38上的结果：
# R方平方值：-0.16207455429497575
# 平均绝对误差MAE：1.9027777777777777
# 均方根误差RMSE：2.2314046398326473
# 在39上的结果：
# R方平方值：0.3847708740094178
# 平均绝对误差MAE：0.8680555555555556
# 均方根误差RMSE：1.136515141415488
# 在40上的结果：
# R方平方值：0.051405325443787064
# 平均绝对误差MAE：0.7118055555555556
# 均方根误差RMSE：0.9947780321927768
# 在41上的结果：
# R方平方值：0.02293089888506794
# 平均绝对误差MAE：0.5833333333333334
# 均方根误差RMSE：0.8740073734751262
# 在42上的结果：
# R方平方值：0.00704418625926273
# 平均绝对误差MAE：1.1770833333333333
# 均方根误差RMSE：1.4469796128487782
# 在43上的结果：
# R方平方值：-0.002718301992180372
# 平均绝对误差MAE：0.8888888888888888
# 均方根误差RMSE：1.1395661942647786
# 在44上的结果：
# R方平方值：0.11460085997382685
# 平均绝对误差MAE：0.9513888888888888
# 均方根误差RMSE：1.241638702145945
# 在45上的结果：
# R方平方值：0.0159090573994074
# 平均绝对误差MAE：1.1354166666666667
# 均方根误差RMSE：1.7940875118009154
# 在46上的结果：
# R方平方值：-0.08511507558218723
# 平均绝对误差MAE：0.7256944444444444
# 均方根误差RMSE：0.9298297335175583
# 在47上的结果：
# R方平方值：-0.0027666421997629698
# 平均绝对误差MAE：1.0798611111111112
# 均方根误差RMSE：1.3881942707464734
# 在48上的结果：
# R方平方值：-0.1499204503732714
# 平均绝对误差MAE：0.9375
# 均方根误差RMSE：1.346291201783626
# 在49上的结果：
# R方平方值：0.06257153758107581
# 平均绝对误差MAE：0.9513888888888888
# 均方根误差RMSE：1.3768926368215255
# 在50上的结果：
# R方平方值：0.10270878927829119
# 平均绝对误差MAE：1.3055555555555556
# 均方根误差RMSE：1.5986105077709065
# 在51上的结果：
# R方平方值：-0.009478512741330158
# 平均绝对误差MAE：0.7465277777777778
# 均方根误差RMSE：1.0391636594449938
# 在52上的结果：
# R方平方值：0.38986427199354956
# 平均绝对误差MAE：0.7152777777777778
# 均方根误差RMSE：0.9646530752325188
# 在53上的结果：
# R方平方值：0.23308752805386346
# 平均绝对误差MAE：0.7534722222222222
# 均方根误差RMSE：1.0189182717197902
# 在54上的结果：
# R方平方值：-0.061895551257253434
# 平均绝对误差MAE：0.7430555555555556
# 均方根误差RMSE：0.9204467514322717
# 在55上的结果：
# R方平方值：-0.010397864497267317
# 平均绝对误差MAE：0.4791666666666667
# 均方根误差RMSE：0.6922186552431729
# 在56上的结果：
# R方平方值：0.36188436830835113
# 平均绝对误差MAE：0.4756944444444444
# 均方根误差RMSE：0.7192781875680029
# 在57上的结果：
# R方平方值：-0.0005532074970679979
# 平均绝对误差MAE：0.5451388888888888
# 均方根误差RMSE：0.7383352144445562
# 在58上的结果：
# R方平方值：0.056467643377751564
# 平均绝对误差MAE：0.5208333333333334
# 均方根误差RMSE：0.7861650943380504
# 在59上的结果：
# R方平方值：0.036382635128716645
# 平均绝对误差MAE：0.6770833333333334
# 均方根误差RMSE：1.0491398593345143
# 在60上的结果：
# R方平方值：-0.1352497988442689
# 平均绝对误差MAE：0.9479166666666666
# 均方根误差RMSE：1.2977009585331196
# 在61上的结果：
# R方平方值：-0.1428835106014814
# 平均绝对误差MAE：0.5277777777777778
# 均方根误差RMSE：0.7728015412913086
# 在62上的结果：
# R方平方值：-0.0932418320155155
# 平均绝对误差MAE：0.6284722222222222
# 均方根误差RMSE：0.8917056066263623
# 在63上的结果：
# R方平方值：0.04104973845199045
# 平均绝对误差MAE：0.7916666666666666
# 均方根误差RMSE：1.0833333333333333
# 在64上的结果：
# R方平方值：0.055545238364851035
# 平均绝对误差MAE：1.0416666666666667
# 均方根误差RMSE：1.5855247992033707
# 在65上的结果：
# R方平方值：0.09275960916068193
# 平均绝对误差MAE：1.0173611111111112
# 均方根误差RMSE：1.3320306135954818
# 在66上的结果：
# R方平方值：0.03594288527818812
# 平均绝对误差MAE：1.46875
# 均方根误差RMSE：1.8437205741531322
# 在67上的结果：
# R方平方值：0.12216624685138544
# 平均绝对误差MAE：1.1840277777777777
# 均方根误差RMSE：1.555679558549539
# 在68上的结果：
# R方平方值：0.21604892236557538
# 平均绝对误差MAE：1.5694444444444444
# 均方根误差RMSE：1.8837757592428859
# 在69上的结果：
# R方平方值：0.3636803353576611
# 平均绝对误差MAE：0.9097222222222222
# 均方根误差RMSE：1.1334558757279536
# 在70上的结果：
# R方平方值：-0.20248447204968945
# 平均绝对误差MAE：0.8854166666666666
# 均方根误差RMSE：1.1226827987756234
# 在71上的结果：
# R方平方值：-0.2370594810435369
# 平均绝对误差MAE：0.9409722222222222
# 均方根误差RMSE：1.4565465244123779

# %%
print(r2_scores)
# Out:
# [0.07092198581560283, 0.05604719764011801, -0.11671190383869723, 0.22012076144237724, 0.022521506007239456, 0.04236227765116096, 0.17981987482827055, 0.19186914619247997, 0.20238095238095233, -0.050292596047833094, 0.15235897889282146, 0.20238095238095233, 0.017631169134807556, 0.06440300404763555, 0.1111566266181927, -0.1019142337717891, 0.2393519034195576, 0.1322103597190425, 0.06175637393767708, -0.06606724003127473, 0.046465376966190686, -1.0109571382533034, 0.06146125268852243, 0.015525664521164217, -0.04360450044071129, 0.23638784113601063, 0.3748688815727981, 0.060994361865709945, -1.1925086049807656, -0.2846456474760346, 0.11920103772291513, -0.30867413388903353, -0.08527330440606895, -0.09102716744236372, -0.08233989464929303, 0.09995350999535102, 0.12561963486881877, 0.3615157941119772, -0.16207455429497575, 0.3847708740094178, 0.051405325443787064, 0.02293089888506794, 0.00704418625926273, -0.002718301992180372, 0.11460085997382685, 0.0159090573994074, -0.08511507558218723, -0.0027666421997629698, -0.1499204503732714, 0.06257153758107581, 0.10270878927829119, -0.009478512741330158, 0.38986427199354956, 0.23308752805386346, -0.061895551257253434, -0.010397864497267317, 0.36188436830835113, -0.0005532074970679979, 0.056467643377751564, 0.036382635128716645, -0.1352497988442689, -0.1428835106014814, -0.0932418320155155, 0.04104973845199045, 0.055545238364851035, 0.09275960916068193, 0.03594288527818812, 0.12216624685138544, 0.21604892236557538, 0.3636803353576611, -0.20248447204968945, -0.2370594810435369]

# %%
def ListMeanStderror(my_list):
    
    # 将列表转换为NumPy数组
    my_array = np.array(my_list)

    # 计算均值
    mean_value = np.mean(my_array)

    # 计算标准差
    std_deviation = np.std(my_array)

    return ('均值为:', mean_value),('标准差为:', std_deviation)

# %%
ListMeanStderror(r2_scores)
# Out:
# (('均值为:', 0.020920163289779057), ('标准差为:', 0.24391771147351396))

# %%
ListMeanStderror(maes)
# Out:
# (('均值为:', 0.966531635802469), ('标准差为:', 0.3603430042978947))

# %%
ListMeanStderror(rmses)
# Out:
# (('均值为:', 1.275143508165223), ('标准差为:', 0.4169820172620036))
